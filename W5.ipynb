# %% [markdown]
# <a href="https://colab.research.google.com/github/northmost2008/northmost2008.github.io/blob/main/W5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
from google.colab import files




url_base = "https://api.ons.gov.uk/timeseries/{}/dataset/PUSF/data"


file_base = "data_ONS-{}.json"


SERIES_ID = ['CPNI', 'CPMX', 'MF78', 'ANNI', 'JW34', 'N445', 'RURC', 'EYOO', 'ANRT']


for i in SERIES_ID: 


   print("------Iteration Starts--------")
   print(i) 
  
   
   URL = url_base.format(i)
   print(URL)
   

   data = requests.get(URL).json()
   print(data)


   fileName = file_base.format(i)
   print(fileName)
   

   print("------Iteration Ends--------")


   with open(fileName, 'w', encoding='utf-8') as f:
     json.dump(data, f, ensure_ascii=False, indent=4)

   files.download(fileName)
# Out:
# ------Iteration Starts--------
# CPNI
# https://api.ons.gov.uk/timeseries/CPNI/dataset/PUSF/data
# ...
